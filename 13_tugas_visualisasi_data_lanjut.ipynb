# %% [markdown]
# ### Soal 1
#
# Anda ditugaskan untuk membuat visualisasi data menggunakan Python untuk menganalisis data sintetis. Gunakan library `numpy` untuk menghasilkan data dan `matplotlib.pyplot` atau `seaborn` untuk visualisasi.
#
# **Tugas:**
#
# 1.  Buat sebuah DataFrame pandas (atau array numpy) yang berisi dua kolom data numerik, `variabel_a` dan `variabel_b`, masing-masing terdiri dari 200 sampel acak yang terdistribusi secara normal (misalnya, dengan mean 0 dan standar deviasi 1).
# 2.  Buatlah **histogram** dari `variabel_a`. Atur jumlah bins (kotak) menjadi 30. Beri judul pada histogram (misal: 'Distribusi Variabel A') dan label sumbu X serta Y.
# 3.  Buatlah **scatter plot** untuk melihat hubungan antara `variabel_a` (sumbu X) dan `variabel_b` (sumbu Y). Beri judul pada scatter plot (misal: 'Hubungan Variabel A vs B') dan label sumbu X serta Y.
# 4.  Tampilkan kedua plot tersebut.
#
# Kode Anda harus menghasilkan dan menampilkan dua plot visualisasi data yang terpisah.

# %%
# TULIS JAWABAN KODE ANDA DISINI
# Pastikan program Anda berjalan tanpa error.

np.random.seed(42) # untuk reproduktifitas
data = pd.DataFrame({
    'variabel_a': np.random.randn(200),
    'variabel_b': np.random.randn(200)
})

# %% [markdown]
# #### Expected Output Soal 1
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Soal 2
#
# Anda diberikan data dalam format dictionary Python yang mewakili nilai skor untuk dua kelompok, 'A' dan 'B'.
#
# ```python
# data = {'group': ['A'] * 20 + ['B'] * 25,
#         'score': [65, 70, 72, 75, 68, 80, 82, 85, 78, 71, 66, 73, 76, 79, 81, 84, 88, 90, 60, 77] +
#                  [88, 90, 92, 95, 85, 80, 78, 98, 100, 82, 81, 84, 86, 89, 91, 93, 96, 99, 75, 70, 83, 87, 94, 97, 72]
# }
# ```
#
# Dengan menggunakan pustaka `pandas` dan `seaborn` atau `matplotlib`, buatlah **box plot** yang membandingkan distribusi `score` antara `group` 'A' dan 'B'.
#
# Setelah membuat plot, jelaskan secara singkat (dalam komentar kode atau print statement) perbedaan utama yang terlihat pada distribusi skor antara kedua kelompok tersebut berdasarkan box plot yang Anda buat.

# %%
# TULIS JAWABAN KODE ANDA DISINI
# Pastikan program Anda berjalan tanpa error.

# %% [markdown]
# #### Expected Output Soal 2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Soal 3
#
# Anda adalah seorang analis data yang bertugas mengeksplorasi dataset sintetis menggunakan visualisasi data lanjutan. Dataset ini mensimulasikan data dengan beberapa variabel numerik dan kategorikal.
#
# Tugas Anda adalah:
#
# 1.  Buat DataFrame pandas dengan 200 baris dan kolom-kolom berikut:
#     *   `fitur_numerik_1`: Bilangan float acak terdistribusi normal (misalnya, mean=50, std dev=15).
#     *   `fitur_numerik_2`: Bilangan float yang berkorelasi positif dengan `fitur_numerik_1` dengan menambahkan noise acak (misalnya, `fitur_numerik_1 * 0.8 + np.random.normal(0, 10, 200)`).
#     *   `kategori`: Nilai kategorikal (misalnya, 'A', 'B', 'C') yang terdistribusi tidak merata (misalnya, 50% A, 30% B, 20% C).
#     *   `nilai_skala`: Bilangan float acak positif yang akan digunakan untuk menentukan ukuran marker pada scatter plot (misalnya, nilai antara 50 hingga 500).
# 2.  Buat sebuah figure `matplotlib` tunggal dengan grid subplot 2x2.
# 3.  **Subplot (0,0 - Kiri Atas):** Gambar **histogram** dari kolom `fitur_numerik_1`. Gunakan 25 bins. Tambahkan judul subplot dan label sumbu yang sesuai.
# 4.  **Subplot (0,1 - Kanan Atas):** Gambar **box plot** dari kolom `nilai_skala`, dikelompokkan berdasarkan `kategori`. Tambahkan judul subplot dan label sumbu yang sesuai.
# 5.  **Subplot (1,0 - Kiri Bawah):** Gambar **scatter plot** yang menunjukkan hubungan antara `fitur_numerik_1` (sumbu x) dan `fitur_numerik_2` (sumbu y). Warnai titik-titik berdasarkan `kategori` dan atur ukuran titik-titik berdasarkan `nilai_skala`. Gunakan library `seaborn` untuk memudahkan pewarnaan dan pengaturan ukuran. Tambahkan judul subplot dan label sumbu yang sesuai. Sertakan legenda untuk warna.
# 6.  **Subplot (1,1 - Kanan Bawah):** Gambar **histogram** dari kolom `fitur_numerik_2`. Gunakan 25 bins. Tambahkan judul subplotdan label sumbu yang sesuai.
# 7.  Tambahkan judul utama pada figure keseluruhan.
# 8.  Hindari tumpang tindih.
#
# Kode Anda harus menghasilkan plot gabungan ini.

# %%
# TULIS JAWABAN KODE ANDA DISINI
# Pastikan program Anda berjalan tanpa error.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Buat DataFrame pandas
np.random.seed(42) # for reproducibility
n_rows = 200

df = pd.DataFrame({
    'fitur_numerik_1': np.random.normal(50, 15, n_rows),
    'nilai_skala': np.random.uniform(50, 500, n_rows)
})

# %% [markdown]
# #### Expected Output Soal 3
#
# Hasil/Nilai plot bisa berbeda tiap orang, karena data dibuat secara random.
#
# ![image.png](data:image/png;base64,...)
