# %% [markdown]
# ### Soal 1
#
# Jelaskan tujuan utama dari Exploratory Data Analysis (EDA) dan mengapa proses ini penting dalam siklus analisis data. Kemudian, uraikan bagaimana teknik analisis data seperti analisis **univariat**, **bivariat**, dan **multivariat** secara bertahap membantu dalam mengungkap struktur, pola, tren, serta potensi anomali dalam kumpulan data.

# %% [markdown]
# <!-- TULIS JAWABAN DESKRIPTIF ANDA DISINI (Markdown) -->
#
# Jawaban Anda:

# %% [markdown]
# ### Soal 2
#
# Anda diberikan data dalam bentuk dictionary Python:
#
# ```python
# data = {
#     'id': [1, 2, 3, 4, 5, 6],
#     'value1': [10, 15, 12, 18, 11, 16],
#     'value2': [100, 150, 120, 500, 110, 160]
# }
# ```
#
# Lakukan tugas-tugas EDA dasar berikut menggunakan library pandas:
# 1.  Muat data dictionary tersebut ke dalam sebuah pandas DataFrame.
# 2.  Hitung dan cetak statistik deskriptif dasar (mean, median, standard deviation, min, max) untuk kolom `value1`.
# 3.  Hitung dan cetak koefisien korelasi Pearson antara kolom `value1` dan `value2`.
# 4.  Berdasarkan statistik deskriptif (khususnya nilai max) dari kolom `value2`, amati apakah ada nilai yang tampak jauh berbeda dari nilai rata-rata/median (potensi outlier). Cetak satu baris komentar mengenai observasi ini.
#
# Gunakan format output yang jelas saat mencetak hasilnya.

# %%
# TULIS JAWABAN KODE ANDA DISINI
# Pastikan program Anda berjalan tanpa error.

# %% [markdown]
# #### Expected Output Soal 2
#
# ```
# Descriptive Statistics for value1:
# Mean: 13.67
# Median: 13.50
# Standard Deviation: 3.14
# Min: 10.00
# Max: 18.00
# --------------------
# Pearson Correlation between value1 and value2:
# 0.78
# --------------------
# Observation on value2: Max value (500.00) is significantly higher than mean (190.00) and median (135.00), suggesting a potential outlier.
# ```
